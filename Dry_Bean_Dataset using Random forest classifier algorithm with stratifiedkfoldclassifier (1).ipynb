# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Loading dataset

# %%
data=pd.read_excel(r"C:\Users\sujat\Downloads\Dry_Bean_Dataset.xlsx")
data
# Out:
#         Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0      28395    610.291       208.178117       173.888747      1.197191
# 1      28734    638.018       200.524796       182.734419      1.097356
# 2      29380    624.110       212.826130       175.931143      1.209713
# 3      30008    645.884       210.557999       182.516516      1.153638
# 4      30140    620.134       201.847882       190.279279      1.060798
# ...      ...        ...              ...              ...           ...
# 13606  42097    759.696       288.721612       185.944705      1.552728
# 13607  42101    757.499       281.576392       190.713136      1.476439
# 13608  42139    759.321       281.539928       191.187979      1.472582
# 13609  42147    763.779       283.382636       190.275731      1.489326
# 13610  42159    772.237       295.142741       182.204716      1.619841
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# ...

# %% [markdown]
# ### Data Preprocessiong

# %%
data.isnull().sum()
# Out:
# Area               0
# Perimeter          0
# MajorAxisLength    0
# MinorAxisLength    0
# AspectRation       0
# Eccentricity       0
# ConvexArea         0
# EquivDiameter      0
# Extent             0
# Solidity           0
# roundness          0
# Compactness        0
# ShapeFactor1       0
# ShapeFactor2       0
# ShapeFactor3       0
# ShapeFactor4       0
# Class              0
# dtype: int64

# %%
data["Class"].value_counts()
# Out:
# DERMASON    3546
# SIRA        2636
# SEKER       2027
# HOROZ       1928
# CALI        1630
# BARBUNYA    1322
# BOMBAY       522
# Name: Class, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
l1=LabelEncoder()
data["Class"]=l1.fit_transform(data["Class"])

# %%
data
# Out:
#         Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0      28395    610.291       208.178117       173.888747      1.197191
# 1      28734    638.018       200.524796       182.734419      1.097356
# 2      29380    624.110       212.826130       175.931143      1.209713
# 3      30008    645.884       210.557999       182.516516      1.153638
# 4      30140    620.134       201.847882       190.279279      1.060798
# ...      ...        ...              ...              ...           ...
# 13606  42097    759.696       288.721612       185.944705      1.552728
# 13607  42101    757.499       281.576392       190.713136      1.476439
# 13608  42139    759.321       281.539928       191.187979      1.472582
# 13609  42147    763.779       283.382636       190.275731      1.489326
# 13610  42159    772.237       295.142741       182.204716      1.619841
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# ...

# %%
x=data.iloc[:,:-1].values
y=data.iloc[:,-1].values

# %% [markdown]
# ## Standardized data

# %%
from sklearn.preprocessing import StandardScaler
s1=StandardScaler()
s2=s1.fit_transform(x)
s2
# Out:
# array([[-0.84074853, -1.1433189 , -1.30659814, ...,  2.40217287,
#          1.92572347,  0.83837103],
#        [-0.82918764, -1.01392388, -1.39591111, ...,  3.10089314,
#          2.68970162,  0.77113842],
#        [-0.80715717, -1.07882906, -1.25235661, ...,  2.23509147,
#          1.84135576,  0.91675514],
#        ...,
#        [-0.37203825, -0.44783294, -0.45047814, ...,  0.28920441,
#          0.33632829,  0.39025114],
#        [-0.37176543, -0.42702856, -0.42897404, ...,  0.22837538,
#          0.2489734 ,  0.03644001],
#        [-0.37135619, -0.38755718, -0.2917356 , ..., -0.12777587,
#         -0.2764814 ,  0.71371948]])

# %%
data1=pd.DataFrame(s2)
data1
# Out:
#              0         1         2         3         4         5         6   \
# 0     -0.840749 -1.143319 -1.306598 -0.631153 -1.565053 -2.185720 -0.841451
# 1     -0.829188 -1.013924 -1.395911 -0.434445 -1.969784 -3.686040 -0.826102
# 2     -0.807157 -1.078829 -1.252357 -0.585735 -1.514291 -2.045336 -0.808704
# 3     -0.785741 -0.977215 -1.278825 -0.439290 -1.741618 -2.742211 -0.773975
# 4     -0.781239 -1.097384 -1.380471 -0.266663 -2.117993 -4.535028 -0.784286
# ...         ...       ...       ...       ...       ...       ...       ...
# 13606 -0.373471 -0.446083 -0.366669 -0.363055 -0.123703  0.153343 -0.378191
# 13607 -0.373334 -0.456336 -0.450053 -0.257015 -0.432979 -0.165141 -0.378662
# 13608 -0.372038 -0.447833 -0.450478 -0.246456 -0.448618 -0.182940 -0.376143
# 13609 -0.371765 -0.427029 -0.428974 -0.266742 -0.380735 -0.106960 -0.372851
# 13610 -0.371356 -0.387557 -0.291736 -0.446224  0.148374  0.389116 -0.375101
#
# ...

# %% [markdown]
# #### Data Balancing

# %%
from imblearn.over_sampling import RandomOverSampler
r1=RandomOverSampler()
x_data,y_data=r1.fit_resample(x,y)

# %%
from collections import Counter
print(Counter(y_data))
# Out:
# Counter({5: 3546, 0: 3546, 1: 3546, 2: 3546, 4: 3546, 6: 3546, 3: 3546})

# %% [markdown]
# ### train-test-split

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_data,y_data,test_size=0.2,random_state=0)

# %% [markdown]
# ### RandomForest

# %% [markdown]
#  #### What is Random Forest model ?
# #### Random Forest is a popular machine learning algorithm that belongs to the supervised learning technique.
# #### It can be used for both Classification and Regression problems in ML.
# #### It is based on the concept of ensemble learning, which is a process of combining multiple classifiers to
# #### solve a complex problem and to improve the performance of the model

# %% [markdown]
# #### Assumptions:
# #### 1) There should be some actual values in the feature variable of the dataset so that the classifier can
# #### predict accurate results rather than a guessed result.
# #### 2) The predictions from each tree must have very low correlations.
# #### Advantages :
# #### 1) Random Forest is capable of performing both Classification and Regression tasks.
# #### 2) It is capable of handling large datasets with high dimensionality.
# #### 3) It enhances the accuracy of the model and prevents the overfitting issue.
# #### Disadvantages :
# #### Although random forest can be used for both classification and regression tasks, it is not more suitable for
# #### Regression tasks. Python Implementation of Random Forest Algorithm

# %% [markdown]
# ### What is Ensemble Techniques ?
# #### Ensemble methods are techniques that create multiple models and then combine them to produce
# #### improved results. Ensemble methods usually produces more accurate solutions than a single model would.

# %%
from sklearn.ensemble import RandomForestClassifier
rd1=RandomForestClassifier(n_estimators=10,criterion="entropy",max_depth=5,random_state=11)
rd1.fit(x_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=5, n_estimators=10,
#                        random_state=11)

# %%
y_pred=rd1.predict(x_test)
y_pred
# Out:
# array([1, 3, 6, ..., 3, 6, 0])

# %%
from sklearn.metrics import accuracy_score
acc=accuracy_score(y_pred,y_test)*100
print(round(acc))
# Out:
# 91

# %% [markdown]
# ### Using StratifiedKFoldClassifier

# %%
from sklearn.model_selection import StratifiedKFold
skf = StratifiedKFold(n_splits=5,shuffle=True, random_state=21)
skf.get_n_splits(x_data,y_data)
print(skf)
# Out:
# StratifiedKFold(n_splits=5, random_state=21, shuffle=True)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict

# %%
for train_data,test_data in skf.split(x_data,y_data):
  x_train,x_test=x_data[train_data],x_data[test_data]
  y_train,y_test=y_data[train_data],y_data[test_data]
  rd1.fit(x_train,y_train)
  scores=cross_val_score(rd1,x_train,y_train,cv=skf)
  y_pred=cross_val_predict(rd1,x_test,y_test)

  print("Checking y_test Balancing.......:",Counter(y_test))
  print(y_pred)
  print(scores)
  print(np.mean(scores)*100)
# Out:
# Checking y_test Balancing.......: Counter({5: 710, 6: 710, 0: 709, 1: 709, 2: 709, 4: 709, 3: 709})
# [3 5 3 ... 6 6 6]
# [0.92019134 0.90936556 0.91513473 0.9148829  0.91085369]
# 91.40856430673236
# Checking y_test Balancing.......: Counter({0: 710, 3: 710, 5: 709, 1: 709, 2: 709, 4: 709, 6: 709})
# [5 5 5 ... 6 6 6]
# [0.91490433 0.91440081 0.90103249 0.90909091 0.91538655]
# 91.09630166136513
# Checking y_test Balancing.......: Counter({1: 710, 5: 709, 0: 709, 2: 709, 4: 709, 6: 709, 3: 709})
# [5 3 5 ... 5 6 6]
# [0.91540785 0.91540785 0.89677744 0.91060186 0.91866029]
# 91.13710605312484
# Checking y_test Balancing.......: Counter({2: 710, 5: 709, 0: 709, 1: 709, 4: 709, 6: 709, 3: 709})
# [5 5 5 ... 6 6 6]
# [0.91389728 0.90080564 0.90835851 0.91891211 0.89977336]
# 90.8349379933014
# Checking y_test Balancing.......: Counter({4: 710, 5: 709, 0: 709, 1: 709, 2: 709, 6: 709, 3: 709})
# [5 5 5 ... 6 6 6]
# [0.91289023 0.9164149  0.9050856  0.89977336 0.91790481]
# ...
